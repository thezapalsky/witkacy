# %% [markdown]
# # Imports

# %%
# code source 
# https://github.com/gordicaleksa/pytorch-neural-style-transfer-johnson

import sys
import os
import random
from google.colab import drive

drive.mount('/content/drive')
NST_path = "/content/drive/MyDrive/NST/"
#sys.path.append(NST_path)

#!python /content/drive/MyDrive/NST/johnson/utils/resource_downloader.py
# !pip install gitPython
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 182 kB 15.3 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.4 MB/s
# ...

# %%
#!python /content/drive/MyDrive/NST/johnson/utils/resource_downloader.py -r mscoco_dataset

# %% [markdown]
# # Load dataset

# %%
def listdir_nohidden(path):
    listed = []
    for f in os.listdir(path):
        if not f.startswith('.'):
            listed.append(f)
    return listed

style_names = listdir_nohidden(NST_path+"dataset/style")
content_names = listdir_nohidden(NST_path+"dataset/content")

# %%
# for style in style_names:
#   print(style)
  #os.system("python /content/drive/MyDrive/NST/johnson/utils/resource_downloader.py")

# ! for file in $content_path; print file; do python process.py --filename /Users/images/$i; done

# %% [markdown]
# # Build random style model

# %%
#s_path = NST_path +"dataset/style/" + style_names[0]
#s_name = random.choice(style_names)
s_name = 'witkacy2.jpg'

# !python /content/drive/MyDrive/NST/johnson/training_script.py --style_img_name $s_name
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/tensorboard/compat/__init__.py", line 42, in tf
# ImportError: cannot import name 'notf' from 'tensorboard.compat' (/usr/local/lib/python3.7/dist-packages/tensorboard/compat/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/NST/johnson/training_script.py", line 171, in <module>
#     train(training_config)
#   File "/content/drive/MyDrive/NST/johnson/training_script.py", line 17, in train
#     writer = SummaryWriter()  # (tensorboard) writer will output to ./runs/ directory by default
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/tensorboard/writer.py", line 246, in __init__
#     self._get_file_writer()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/tensorboard/writer.py", line 277, in _get_file_writer
# ...

# %%
from google.colab import runtime
runtime.unassign()

# %% [markdown]
# # Run specific model for all content imgs

# %%
# %%time

c_name = random.choice(content_names)
c_path = NST_path +"dataset/content/" + c_name #content_names[1]
m_name = "style_wyspianski1_datapoints_4000_cw_1.0_sw_400000.0_tw_0.pth"

#for c_name in content_names:
c_path = NST_path +"dataset/content/" + c_name #content_names[1]
#os.system("python /content/drive/MyDrive/NST/johnson/stylization_script.py --content_input "+c_path+" --model_name "+m_name)

# !python /content/drive/MyDrive/NST/johnson/stylization_script.py --content_input $c_path --model_name $m_name
# Out:
# Figure(640x480)
# CPU times: user 55.7 ms, sys: 14.8 ms, total: 70.5 ms
# Wall time: 6.84 s

# %%
# %%time
# !python /content/drive/MyDrive/NST/johnson/stylization_script.py --content_input $c_path --model_name $m_name
# Out:
# Figure(640x480)
# CPU times: user 54.7 ms, sys: 8.26 ms, total: 63 ms
# Wall time: 5.84 s
