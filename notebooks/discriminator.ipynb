# %% [markdown]
# # Imports

# %%
# code source
# https://github.com/aigagror/style-transfer-quality

# !pip install -U tensorflow-addons

import sys
import os
import random

NST_path = "/content/drive/MyDrive/NST/"

def listdir_nohidden(path):
    listed = []
    for f in os.listdir(path):
        if not f.startswith('.'):
            listed.append(f)
    return listed

style_names = listdir_nohidden(NST_path+"dataset/style")
content_names = listdir_nohidden(NST_path+"dataset/content")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
##%%time
#s_name = random.choice(style_names)
#s_name = 'witkacy10.jpg'

#run_path = NST_path + 'discriminator/run.py'
#style_path = NST_path + 'discriminator/imgs/starry_night.jpg'

#!python $run_path --style_image=$style_path --imsize=512 --loss=wass --sample_size 1024

# %%
#python run.py --style_image=imgs/starry_night.jpg --imsize=512 --disc_model=mlp 
# check this also this method

# %% [markdown]
# # Perform Style Transfer

# %%
# %%time
s_name = 'witkacy2.jpg'
#c_name = random.choice(content_names)
c_name = 'content14.jpg'

run_path = NST_path + 'discriminator/run.py'
style_path = NST_path + 'dataset/style/'+s_name
content_path = NST_path + 'dataset/content/'+c_name

#!python $run_path --style_image=$style_path --content_image=$content_path --imsize=512 --loss=wass --train_steps=10000 --verbose=1
# !python $run_path --style_image=$style_path --content_image=$content_path --imsize=512 --disc_model=mlp --train_steps=10000 --verbose=1
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
from google.colab import runtime
runtime.unassign()
