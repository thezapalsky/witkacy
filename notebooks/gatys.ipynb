# %% [markdown]
# # NST dashboard

# %% [markdown]
# ### Notes
# - my cpu -> ~4mins
# - colab cpu -> 1min 30sec
# - colab gpu -> 30sec
# - colab tpu -> 1min 42sec

# %% [markdown]
# # Code

# %%
import sys
# caution: path[0] is reserved for script path (or '' in REPL)
NST_path = "/content/drive/MyDrive/NST/gatys/"
sys.path.append(NST_path)
NST_path = "/content/drive/MyDrive/NST/"
import gatys_vanilla
import os
import random

def listdir_nohidden(path):
    listed = []
    for f in os.listdir(path):
        if not f.startswith('.'):
            listed.append(f)
    return listed

style_names = listdir_nohidden(NST_path+"dataset/style")
content_names = listdir_nohidden(NST_path+"dataset/content")
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
#   0%|          | 0.00/548M [00:00<?, ?B/s]

# %%
# %%time

# # content_name = "content19.jpg"
# for content_name in content_names:
#   for style_name in style_names:
#     content_img_path = NST_path+"dataset/content/" + content_name
#     style_img_path = NST_path+"dataset/style/"+style_name
#     title = content_name + " x " + style_name

#     print("running:", content_img_path, style_img_path)
#     gatys_vanilla.run_algo(content_img_path,
#                           style_img_path, 
#                           out_title=title)


# content_name = content_names[0]
# style_name = style_names[0]

c_pairs = ["content14.jpg", "content16.jpg", "content22.jpg", "content25.jpg", "content27.jpg"]
s_pairs = ["witkacy2.jpg", "matejko5.jpg", "beksinski1.jpg", "wyspianski1.jpg", "witkacy5.jpg"]


for i in range(5):
  content_name = c_pairs[i]
  style_name = s_pairs[i]
  #style_name = random.choice(style_names)
  #content_name = random.choice(content_names)
  
  content_img_path = NST_path+"dataset/content/" + content_name
  style_img_path = NST_path+"dataset/style/"+style_name
  title = content_name + " x " + style_name

  print("running:", content_img_path, style_img_path)
  gatys_vanilla.run_algo(content_img_path,
                        style_img_path, 
                        out_title=title)
# Out:
# running: /content/drive/MyDrive/NST/dataset/content/content14.jpg /content/drive/MyDrive/NST/dataset/style/witkacy2.jpg
# /content/drive/MyDrive/NST/gatys/gatys_vanilla.py:148: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /content/drive/MyDrive/NST/gatys/gatys_vanilla.py:149: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# 29.272507905960083
# running: /content/drive/MyDrive/NST/dataset/content/content16.jpg /content/drive/MyDrive/NST/dataset/style/matejko5.jpg
# 22.88735294342041
# ...
